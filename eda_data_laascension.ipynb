# %%
import pandas as pd

# %%
df_contratos = pd.read_csv("data/Contratos.csv", sep=';')
df_contratos.head(-5)
# Out:
#         Doc entry             Nombre UEN         Nombre Sub UEN  \
# 0          265278            EMPRESARIAL            EMPRESARIAL
# 1          265279            EMPRESARIAL            EMPRESARIAL
# 2          265280            EMPRESARIAL            EMPRESARIAL
# 3          265281            EMPRESARIAL            EMPRESARIAL
# 4          265284            EMPRESARIAL            EMPRESARIAL
# ...           ...                    ...                    ...
# 391290     166830  ORGANISMOS DEL ESTADO  ORGANISMOS DEL ESTADO
# 391291     166831  ORGANISMOS DEL ESTADO  ORGANISMOS DEL ESTADO
# 391292     166832  ORGANISMOS DEL ESTADO  ORGANISMOS DEL ESTADO
# 391293     166833  ORGANISMOS DEL ESTADO  ORGANISMOS DEL ESTADO
# 391294     166834  ORGANISMOS DEL ESTADO  ORGANISMOS DEL ESTADO
#
#         Convenio actual          Nombre Convenio Fecha real contrato  \
# 0                  1621   MEMBRESIA VIP CLUB SAS           1/10/2018
# ...

# %%
df_complementarios = pd.read_csv("data/Complementarios.csv", sep=';')
df_complementarios.head(-5)
# Out:
#         Docentry Sexo Código Seguro  \
# 0         280786    M      S04_0002
# 1         280786    M      S01_0151
# 2         282115    M      S01_0151
# 3         282115    M      S04_0002
# 4         280330    M      S01_0151
# ...          ...  ...           ...
# 265175    436876    F      S04_0002
# 265176    461681    M      S01_0035
# 265177    374936    M      S04_0002
# 265178    374936    M      S01_0155
# 265179    374936    M      S01_0157
#
#                                             Nombre Seguro F. nacimiento  \
# 0                          ASISTENCIA VIAL HOGAR Y MEDICA    23/01/1999
# 1        SEGURO ACCIDENTES  CON ADICIONALES 5M - INCLUIDO    23/01/1999
# 2        SEGURO ACCIDENTES  CON ADICIONALES 5M - INCLUIDO    11/10/1995
# 3                          ASISTENCIA VIAL HOGAR Y MEDICA    11/10/1995
# 4        SEGURO ACCIDENTES  CON ADICIONALES 5M - INCLUIDO    28/01/1992
# ...                                                   ...           ...
# ...

# %%
df_serfun = pd.read_csv("data/SerFun.csv", sep=";")
df_serfun.head(-5)
# Out:
#         DocNum     Tipo Prestacion  CreateDate  DocEntry  \
# 0      2002468  Previsión Exequial  10/05/2019    7576.0
# 1      2025926         No Prestado  13/02/2022  463523.0
# 2      2025551         No Prestado  30/01/2022   23746.0
# 3      2025373         No Prestado  24/01/2022   49526.0
# 4      2025790          Particular   7/02/2022       NaN
# ...        ...                 ...         ...       ...
# 40215  2019162  Previsión Exequial  14/05/2021  378253.0
# 40216  2019375         No Prestado  21/05/2021  412370.0
# 40217  2019357  Previsión Exequial  20/05/2021  421641.0
# 40218  2019431  Previsión Exequial  23/05/2021  438381.0
# 40219  2019717  Previsión Exequial  31/05/2021   45309.0
#
#        Ciudad Fallecimiento Fecha Fallecimiento  Edad              Causa  \
# 0                   11001.0          10/05/2019    26         ACCIDENTAL
# 1                   13430.0          12/02/2022    68            NATURAL
# ...

# %%
df_beneficiarios = pd.read_csv("data/Beneficiarios.csv", sep="\t", encoding='utf-16-le')
df_beneficiarios.head(-5)
# Out:
#                #  DocEntry Sexo Numero de Documento Parentesco  \
# 0              1         1    F            31418546       HERM
# 1              2         1    F            22103662       TITU
# 2              3         1    M         96052118163       SOBR
# 3              4         1    M         98091958470       CUÑA
# 4              5         1    F            43462250       PRIM
# ...          ...       ...  ...                 ...        ...
# 2620551  2620552    473615    F          1118638899       HJOA
# 2620552  2620553    473615    M          1118368980       SOBR
# 2620553  2620554    473615    F          1117552118       HJOA
# 2620554  2620555    473615    M          1118370206       HJOA
# 2620555  2620556    473615    F            40611347       ESPO
#
#         Fecha Nacimiento Fecha Retiro Fecha Siniestro Fecha Crea Contrato  \
# 0             24/10/1972          NaN             NaN          04/11/2008
# ...
